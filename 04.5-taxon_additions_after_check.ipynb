# %%
import pandas as pd
import numpy as np
from BK_Tree import BKTree
import re
import string
from dead_processing_utils import *
from file_processing_utils import *

# %%
determination_key = pd.read_csv("data/NoAuthorTest.csv")
determination_key['no_author'] = determination_key['no_author'].apply(lambda x: punctStrip(x))

# %%
checked_names_to_add = pd.read_csv('output/to_add_against_kew.csv')
accepted_name_in_db = checked_names_to_add[checked_names_to_add['accepted_name'].isin(determination_key['no_author'])]

# %%
accepted_name_in_db.head(50)
# Out:
#                                                   name  \
# 0                                   AZARA INTEGRIFOLIA
# 6                                     (Dormant orchid)
# 7                                         Dwarf grass)
# 10                                       (Water grass)
# 12                          (Composite Penstemom liko*
# 17                                   (Cichoraea Tribe)
# 20                             wiry stemmed, deciduous
# 31                                         Umbe litter
# 32                                           DISCARDED
# 34                                   Portulacaceae sp.
# 36                                                 NOC
# 37                                              "bulb"
# 42                                     Abutilon hybrid
# 43                          Abutilon avicennae Gaertn.
# 61   Acacia Edgeworthii T. Anders    (Synonym A. so...
# 67                            Acacia juniperina Willd.
# 69                          Acacia koahawaiiensis Rock
# 70                               Acacia linearis Sims.
# 86                       Acanthocereus (Berg.) Br & R.
# 96                   circinatum Acer corcomati, Pursh.
# 98                          Acer mono Maxim. var. mono
# 99                         Acer syriacum Boiss. & Gail
# 100    Achillea Lewisii (A. tomentosa X    A. argentea
# 107                             Achras zapota not some
# 108                     Achras Arachis Zapota (ZAPOTA)
# 113            Aciphylla scott -thomsonii Ckn. & Allen
# 117                             Aconitum excelsum Rehb
# 125                                      Actinostachys
# 140               Adromischus ernianus Hutch, sp. nov.
# 141                      Adromischus festivus C.A. Sm.
# 142     Adromischus jasminiflorus (Salm- - -Dyck) Lem.
# 143                      Adromischus libanoticus Hort.
# 145                    Adromischus pulchellus Hutchis.
# 146                  Adromischus rhynsdorpensis Hutch.
# 148       Adromischus suther landensis Hutch.,sp. nov.
# 150                                Aechmaea fosteriana
# 155                                  Aegilops ovata L.
# 156                              Aegilops squarrosa L.
# 157                        Aegilops triaristata Willd.
# 161              Aeibuyn cabaruebse (L.) Webb & Berth.
# 162      Aeonium arboreum W.S.B. var. variegatum Hort.
# 163  Aeonium spathulatum (Horn. ) Praeg. var. cruen...
# 168            Aerides racemeformis (see note on back)
# 173                      Agapetes Hookeri C. B. Clarke
# 178                               Agave Filifera Salm.
# 180                               Agave Parryi Engelm.
# 182       Agave grandidentata Jacobi xylonacantha Salm
# 205                        Allium Sp. acuminatum Hook.
# 208                      Allium cepa L. var. viviparum
# 209  Allium fimbriatum Wats. var. diabloensis Ownby...
#
#                        checked_synonym                accepted_name  \
# 0                   Azara integrifolia           Azara integrifolia
# 6                                Doria                     Solidago
# 7                                Waria                      Xylopia
# 10                                 Ate                    Habenaria
# 12                     Penstemon minor          Penstemon anguineus
# 17                           Wichuraea                      Bomarea
# 20                                Aira                         Aira
# 31                                Hebe                     Veronica
# 32                            Discaria                     Discaria
# 34                        Portulacaria                 Portulacaria
# 36                                 Nil                      Ipomoea
# 37                               Bulga                        Ajuga
# 42                            Abutilon                     Abutilon
# 43                  Abutilon avicennae         Abutilon theophrasti
# 61                              Acacia                       Acacia
# 67                   Acacia juniperina            Acacia ulicifolia
# 69                              Acacia                       Acacia
# 70                     Acacia linearis             Acacia linifolia
# 86                       Acanthocereus                Acanthocereus
# 96                                Acer                         Acer
# 98                                Acer                         Acer
# 99                       Acer syriacum            Acer obtusifolium
# 100                           Achillea                     Achillea
# 107                      Achras zapota             Manilkara zapota
# 108                             Achras                    Manilkara
# 113                          Aciphylla                    Aciphylla
# 117                  Aconitum excelsum      Aconitum septentrionale
# 125                      Actinostachys                     Schizaea
# 140                  Adromischus nanus            Adromischus nanus
# 141               Adromischus festivus          Adromischus cooperi
# 142          Adromischus jasminiflorus  Adromischus caryophyllaceus
# 143                        Adromischus                  Adromischus
# 145             Adromischus pulchellus         Adromischus alstonii
# 146                        Adromischus                  Adromischus
# 148                        Adromischus                  Adromischus
# 150                           Aechmaea                      Aechmea
# 155                     Aegilops ovata            Aegilops neglecta
# 156                 Aegilops squarrosa         Aegilops triuncialis
# 157               Aegilops triaristata            Aegilops neglecta
# 161                             Ambuya                 Aristolochia
# 162                            Aeonium                      Aeonium
# 163  Aeonium spathulatum var. cruentum          Aeonium spathulatum
# 168                            Aerides                      Aerides
# 173                           Agapetes                     Agapetes
# 178                              Agave                        Agave
# 180                              Agave                        Agave
# 182                Agave grandidentata                Agave horrida
# 205                             Allium                       Allium
# 208         Allium cepa var. viviparum                  Allium cepa
# 209                             Allium                       Allium
#
#                              author
# 0                       Ruiz & Pav.
# 6                                L.
# 7                                L.
# 10                           Willd.
# 12                           Eastw.
# 17                            Mirb.
# 20                               L.
# 31                               L.
# 32                            Hook.
# 34                            Jacq.
# 36                               L.
# 37                               L.
# 42                            Mill.
# 43                           Medik.
# 61                            Mill.
# 67                  (Salisb.) Court
# 69                            Mill.
# 70                   (Vent.) Willd.
# 86         (Engelm.) Britton & Rose
# 96                               L.
# 98                               L.
# 99                              Sm.
# 100                              L.
# 107                    (L.) P.Royen
# 108                          Adans.
# 113           J.R.Forst. & G.Forst.
# 117                          Koelle
# 125                             Sm.
# 140               (N.E.Br.) Poelln.
# 141                (Baker) A.Berger
# 142                  (Burm.f.) Lem.
# 143                            Lem.
# 145  (Schönland & Baker f.) C.A.Sm.
# 146                            Lem.
# 148                            Lem.
# 150                     Ruiz & Pav.
# 155                 Req. ex Bertol.
# 156                              L.
# 157                 Req. ex Bertol.
# 161                              L.
# 162                 Webb & Berthel.
# 163               (Hornem.) Praeger
# 168                           Lour.
# 173                  D.Don ex G.Don
# 178                              L.
# 180                              L.
# 182                  Lem. ex Jacobi
# 205                              L.
# 208                              L.
# 209                              L.
