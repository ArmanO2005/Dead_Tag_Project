# %%
import pandas as pd
import numpy as np
from BK_Tree import BKTree
import re
import string
from dead_processing_utils import *
from file_processing_utils import *

# %%
collector_template = strip('ucbg_templates/ucbg_4-0-0_organization-template.csv')

# %%
families = pd.read_csv('output/taxon_upload/1-taxon_upload_FAMILIES.csv')
families['termDisplayName'] = families['termDisplayName'].str.upper()
families.to_csv('output/taxon_upload/1-taxon_upload_FAMILIES.csv', index=False)
